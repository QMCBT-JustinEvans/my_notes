# %%
import pandas as pd
import os

# %% [markdown]
# # Acquire
# Data can be retrieved from the [World Health Organization (WHO)](https://www.who.int//)
# * [Age-standardized estimates of current tobacco use, tobacco smoking and cigarette smoking
# Data by country](https://apps.who.int/gho/data/view.main.TOBAGESTDCURRv)

# %%
# Relative to current location
#  /1.   /2.   /3.       /4.       /5.    /6.      /7. 
# /Users/qmcbt/Documents/Education/Codeup/Projects/Smoking/ **(file is here)**
# /1.    /2    /3.                 /4.       
# /Users/qmcbt/codeup-data-science/my_notes/ **(I am here)**
#          ../                 ../
# I must go up 2 levels to reach first shared parent folder

df = pd.read_csv('../../Documents/Education/Codeup/Projects/Smoking/M_Est_tob_curr_std,M_Est_smk_curr_std,M_Est_cig_curr_std.csv')

# %%
df
# Out:
#        Unnamed: 0 Unnamed: 1  \
# 0         Country       Year
# 1     Afghanistan       2025
# 2     Afghanistan       2023
# 3     Afghanistan       2020
# 4     Afghanistan       2019
# ...           ...        ...
# 1473     Zimbabwe       2018
# 1474     Zimbabwe       2015
# 1475     Zimbabwe       2010
# 1476     Zimbabwe       2005
# 1477     Zimbabwe       2000
#
#      Estimate of current tobacco use prevalence (%) (age-standardized rate)  \
# 0                                            Both sexes
# 1                                                    21
# 2                                                   8.4
# 3                                                  23.3
# 4                                                  23.8
# ...                                                 ...
# 1473                                               12.1
# 1474                                               13.6
# 1475                                               15.6
# ...

# %%
df.shape
# Out:
# (1478, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1478 entries, 0 to 1477
# Data columns (total 11 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Unnamed: 0                                                                      1478 non-null   object
#  1   Unnamed: 1                                                                      1478 non-null   object
#  2   Estimate of current tobacco use prevalence (%) (age-standardized rate)          1477 non-null   object
#  3   Estimate of current tobacco use prevalence (%) (age-standardized rate).1        1477 non-null   object
#  4   Estimate of current tobacco use prevalence (%) (age-standardized rate).2        1477 non-null   object
#  5   Estimate of current tobacco smoking prevalence (%) (age-standardized rate)      1477 non-null   object
# ...

# %%
# Number of Unique Countries
df['Unnamed: 0'].nunique()
# Out:
# 166

# %%
# List of Unique Countries
df['Unnamed: 0'].unique()
# Out:
# array(['Country', 'Afghanistan', 'Albania', 'Algeria', 'Andorra',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Côte d'Ivoire", 'Croatia', 'Cuba', 'Cyprus',
#        'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Fiji', 'Finland', 'France',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala',
# ...

# %%
# Number of Unique Years
df['Unnamed: 1'].nunique()
# Out:
# 10

# %%
# List of Unique Years
df['Unnamed: 1'].unique()
# Out:
# array(['Year', ' 2025', ' 2023', ' 2020', ' 2019', ' 2018', ' 2015',
#        ' 2010', ' 2005', ' 2000'], dtype=object)

# %%
df.describe(include='all')
# Out:
#                               Unnamed: 0 Unnamed: 1  \
# count                               1478       1478
# unique                               166         10
# top     Lao People's Democratic Republic       2020
# freq                                   9        165
#
#        Estimate of current tobacco use prevalence (%) (age-standardized rate)  \
# count                                                1477
# unique                                                417
# top                                                  28.4
# freq                                                   13
#
#        Estimate of current tobacco use prevalence (%) (age-standardized rate).1  \
# count                                                1477
# unique                                                529
# top                                                  36.3
# freq                                                    9
#
# ...
